# %% [markdown]
# # Sportbet — EDA
# Quick exploration of the xG signals database. Run the pipeline first:
# ```
# python run.py all
# ```

# %%
import sqlite3, pandas as pd
import sys; sys.path.append('..')
import config
conn = sqlite3.connect(config.DB_PATH)
matches = pd.read_sql_query('SELECT * FROM matches', conn)
shots = pd.read_sql_query('SELECT * FROM shots', conn)
signals = pd.read_sql_query('SELECT * FROM signals', conn)
len(matches), len(shots), len(signals)

# %%
results = pd.read_csv('../results/signal_ev_table.csv')
results.head(20)
